# %% [markdown]
# #### Import required libraries and functions
# ##### Some other libraries are imported in later sections, but these are the most salient ones

# %%
import torch

from bams.data import KeypointsDataset
from bams.models import BAMS
from bams import compute_representations
from custom_dataset_w_labels import load_data, load_annotations

import numpy as np
import os 
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## When changing between models (you were working with one and now you want to work with another), I recommened restarting and clearing the outputs-- this is the easiest way to make sure you don't miss running a cell

# %% [markdown]
# # Load the data
# #### input a path to a trained bams model and dlc csvs --> get bams features embedding

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
'''
input the path to the bams model folder and the dlc data folder 

the bams model folder should have a bams model (ending in '.pt') in it
the code recognizes the model by it beginning with 'bams-custom' and ending with '.pt' therefore, it is important to make sure that only one exists per folder

the data folder should be organized with subfolders named with the species (label)
each subfolder contains dlc csvs. each csv should contain the same number of datapoints (frames) 

if choosing to load bsoid features, it will take around ~40 min for 119 samples
alternatively, you can load 'embeddings.pth' later in the code (skip the next cell and uncomment the line under the next User input section)

feature_processing and model_folder need to match (dimensions of model matches the dimensions of input features)
see the ppt Documentation for model:feature match

note, for bsoid features, I skipped the adaptive filtering step that is seen in the original algorithm-- not all of the csvs had a likelihood distribution that worked with the filtering 
'''

### options are subtract_centroid (x and y coordinates with the centroid subtracted for each frame), bsoid (x and y coordinates are used to compute bsoid features), or None (x and y coordinates) ###
feature_processing = 'subtract_centroid' 

### input path to model folder here ###
### change the model to match what features you want to extract-- see the ppt Documentation for model:feature match ###
model_folder = r"X:\MaryBeth\BAMS\bams_collab\models\bams-custom-2024-08-29-15-48-48_0.8" 

### input path to data folder here ###
### you don't need to change this unless you want to change the input dataset ###
dlc_data_folder = r"X:\MaryBeth\BAMS\bams_collab\models\threshold_0.8\movement"

# %%
with os.scandir(model_folder) as entries:
    for entry in entries:
        if entry.is_file() and entry.name.startswith('bams-custom') and entry.name.endswith('.pt'):
            model_name = entry
            print("Loading model", model_name)
            print()
            
model_path = os.path.join(model_folder, model_name)
annotations_path = os.path.join(model_folder,"video_labels.csv")

hoa_bins = 32
model_input = load_data(dlc_data_folder, model_folder, feature_processing = feature_processing, create_csv = False) ### set to True if you want to re create the mapping from bams to the original data csvs-- you only need to do this if you want to change the input dataset ### 
annotations, eval_utils = load_annotations(annotations_path)

dataset = KeypointsDataset(
        keypoints=model_input,
        cache=False,
        hoa_bins=hoa_bins,
        annotations=annotations,
        eval_utils=eval_utils
    )

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = BAMS(
        input_size=dataset.input_size,
        short_term=dict(num_channels=(64, 64, 64, 64), kernel_size=3),
        long_term=dict(num_channels=(64, 64, 64, 64, 64), kernel_size=3, dilation=4),
        predictor=dict(
            hidden_layers=(-1, 256, 512, 512, dataset.target_size * hoa_bins)
        ),
    ).to(device)
model.load_state_dict(torch.load(model_path))
model.eval()

embeddings = compute_representations(model, dataset, device)
# Out:
# Loading model <DirEntry 'bams-custom-2024-08-29-15-48-48.pt'>
#
# Processing video: 20231127_FrontDLC_resnet50_RatBody_CombinedApr29shuffle1_1100000
FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_97200_100800
# x:  [[ -92.79675293  -31.55163574   15.98132324 ...   23.58044434
#    139.87341309 -188.63122559]
#  [ -82.03052436  -20.82996284   27.21422662 ...   33.9992608
#    150.95641412 -370.42639838]
#  [ -82.37162272  -20.90946452   27.07515462 ...   33.98421224
#    150.86153158 -370.41923014]
#  ...
#  [ 141.79806197   88.41762984   38.57052291 ... -123.73361527
#   -270.15304887 -382.07794511]
#  [ 134.98808797   83.57542928   35.61223348 ... -125.73383586
#   -271.84491984 -382.44208781]
#  [ 127.48438517   81.17066447   32.02930705 ... -120.97612508
#   -265.02162679 -377.04616292]]
# y:  [[ 53.7668457    2.73095703 -17.26708984 ... 131.16503906  19.11425781
#    24.09814453]
#  [ 58.10236274   7.10529243 -12.40911187 ... 135.58331977  23.38190375
#   -49.7782525 ]
#  [ 58.82054308   7.24705675 -12.39942763 ... 135.40574816  23.32298448
#   -49.82154677]
#  ...
#  [ 67.71641139   4.25962428 -43.20998021 ...  78.67600612  26.78696803
#   147.96140651]
#  [ 70.37260607   7.02910021 -41.73975966 ...  78.72136095  27.2811754
#   147.81291368]
#  [ 69.69349501  10.04762099 -42.29411485 ...  76.97840712  25.74220106
#   146.11366102]]
# Number of samples: 3600
# Number of keypoints: 20
# keypoints shape: (3600, 20, 2)
# Number of features: 2
# Number of chunks: 1
# All keypoints reshaped shape: (119, 3600, 40)
# 100%|██████████| 40/40 [00:00<00:00, 46.50it/s]
# c:\Users\MaryBeth\anaconda3\envs\bams_env\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 100%|██████████| 30/30 [00:14<00:00,  2.08it/s]

# %% [markdown]
# # Plot PCAs of sequence level embeddings
# #### explore sequence level (averaged over the 2 min samples) embeddings

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### If you want to load a previously computed embedding, uncomment the line below ###

# embeddings = torch.load(os.path.join(model_folder,'embeddings.pth'))

# %%
''' 
each embedding (short, long, all) should be shape (n samples (total csvs), n frames per sample, n bams features)

sequence level embeddings (for each sample, averaged over all of the frames for each feature) are used for the 2D PCA plots, Pearson correlations, and species predictions
'''

### retrieve frame level embeddings ###

short_term = embeddings['short_term']
long_term = embeddings['long_term']
all_embeddings = torch.cat([short_term, long_term], dim=2)

print("short_term: ", np.shape(short_term))
print("long_term: ", np.shape(long_term))
print("all_embeddings: ", np.shape(all_embeddings))
print("")

### compute sequence level embeddings of the bams features by averaging over the frames for each sample ###

short_term_seq = torch.mean(short_term, dim=1, keepdim=False)
long_term_seq = torch.mean(long_term, dim=1, keepdim=False)
all_embeddings_seq = torch.cat([short_term_seq, long_term_seq], dim=1)

print("short_term seq: ", np.shape(short_term_seq))
print("long_term seq: ", np.shape(long_term_seq))
print("all_embeddings: ", np.shape(all_embeddings_seq))
# Out:
# short_term:  torch.Size([119, 3600, 64])
# long_term:  torch.Size([119, 3600, 64])
# all_embeddings:  torch.Size([119, 3600, 128])
#
# short_term seq:  torch.Size([119, 64])
# long_term seq:  torch.Size([119, 64])
# all_embeddings:  torch.Size([119, 128])

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### If you want to save a newly computed embedding, uncomment the line below ###

# torch.save({'short_term': short_term, 'long_term': long_term}, os.path.join(model_folder,'embeddings.pth'))

# %% [markdown]
# ## 2D PCA

# %%
### fit PCA for each sequence level embedding ###

pca = PCA(n_components=2)
pca.fit(short_term_seq)
short_term_pca = pca.transform(short_term_seq)
ev_short_term = pca.explained_variance_ratio_

pca = PCA(n_components=2)
pca.fit(long_term_seq)
long_term_pca = pca.transform(long_term_seq)
ev_long_term = pca.explained_variance_ratio_

pca.fit(all_embeddings_seq)
all_pca = pca.transform(all_embeddings_seq)
ev_all = pca.explained_variance_ratio_

### print the explaiened variance for each emebddings ###

print("ev short term: ", ev_short_term)
print("ev long term: ", ev_long_term)
print("ev all: ", ev_all)
# Out:
# ev short term:  [0.41205977 0.17192782]
# ev long term:  [0.4193873  0.17242918]
# ev all:  [0.40146875 0.1639103 ]

# %% [markdown]
# #### Create mapping for PCA legend

# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

### load the mapping from bams to the original data csvs ### 

df = pd.read_csv(annotations_path)

num_segments = len(df)
video_names = df['video_name'].unique()
unique_labels = df['label'].unique()
label_mapping = {label: index for index, label in enumerate(unique_labels)}

print(label_mapping)

video_label_mapping = df.groupby('video_name')['label'].first().to_dict()

print(video_label_mapping)

consolidated_video_label_mapping = {}

for video_name, label in video_label_mapping.items():
    ### extract the date from each video name ###
    starting_number = video_name.split('_')[0]
    
    ### add each unique date to the consolidated mapping ###
    if starting_number not in consolidated_video_label_mapping:
        consolidated_video_label_mapping[starting_number] = label

print(consolidated_video_label_mapping)

videos_label_1 = [video for video, label in consolidated_video_label_mapping.items() if label == 'treeshrew']
videos_label_0 = [video for video, label in consolidated_video_label_mapping.items() if label == 'rat']

print(videos_label_1)
print(videos_label_0)

count_treeshrew = df[df['label'] == 'treeshrew'].shape[0]
count_rat = df[df['label'] == 'rat'].shape[0]

print("num rats: ", count_rat)
print("num treeshrews: ", count_treeshrew)

### make color gradients for each species ### 
num_rat_videos = len(videos_label_0)
num_treeshrew_videos = len(videos_label_1)

rat_colormap = plt.cm.summer(np.linspace(0, 1, num_rat_videos))
ts_colormap = plt.cm.cool(np.linspace(0, 1, num_treeshrew_videos))

video_color_mapping = {video: tuple(ts_colormap[i]) for i, video in enumerate(videos_label_1)}
video_color_mapping.update({video: tuple(rat_colormap[i]) for i, video in enumerate(videos_label_0)})

print(video_color_mapping)

def extract_numbers(video_name):
    match = re.match(r'(\d+)', video_name)
    return match.group(1) if match else video_name

video_number_color_mapping = {extract_numbers(video): color for video, color in video_color_mapping.items()}
# Out:
# {'rat': 0, 'treeshrew': 1}
# {'20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_0_3600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_100800_104400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_10800_14400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_18000_21600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_21600_25200': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_28800_32400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_32400_36000': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_36000_39600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_43200_46800': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_46800_50400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_50400_54000': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_54000_57600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_57600_61200': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_61200_64800': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_64800_68400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_68400_72000': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_72000_75600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_7200_10800': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_75600_79200': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_79200_82800': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_82800_86400': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_86400_90000': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_90000_93600': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_93600_97200': 'treeshrew', '20230609_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_97200_100800': 'treeshrew', '20230613_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_0_3600': 'treeshrew', '20230613_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_3600_7200': 'treeshrew', '20230613_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_7200_10800': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_0_3600': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_100800_104400': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_104400_108000': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_108000_111600': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_10800_14400': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_111600_115200': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_115200_118800': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_14400_18000': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_18000_21600': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_21600_25200': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_25200_28800': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_28800_32400': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_32400_36000': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_3600_7200': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_64800_68400': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_68400_72000': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shuffle1_1060000_72000_75600': 'treeshrew', '20230614_FrontDLC_resnet50_treeshrewMBMay20shu ...
# {'20230609': 'treeshrew', '20230613': 'treeshrew', '20230614': 'treeshrew', '20230615': 'treeshrew', '20230616': 'treeshrew', '20231127': 'rat', '20231128': 'rat', '20231129': 'rat', '20231130': 'rat'}
# ['20230609', '20230613', '20230614', '20230615', '20230616']
# ['20231127', '20231128', '20231129', '20231130']
# num rats:  44
# num treeshrews:  75
# {'20230609': (0.0, 1.0, 1.0, 1.0), '20230613': (0.25098039215686274, 0.7490196078431373, 1.0, 1.0), '20230614': (0.5019607843137255, 0.4980392156862745, 1.0, 1.0), '20230615': (0.7529411764705882, 0.24705882352941178, 1.0, 1.0), '20230616': (1.0, 0.0, 1.0, 1.0), '20231127': (0.0, 0.5, 0.4, 1.0), '20231128': (0.3333333333333333, 0.6666666666666666, 0.4, 1.0), '20231129': (0.6666666666666666, 0.8333333333333333, 0.4, 1.0), '20231130': (1.0, 1.0, 0.4, 1.0)}

# %% [markdown]
# #### 2D Visualization with Matplotlib

# %%
''' 
for this dataset, there was 1 rat and 2 treeshrews (indicated by (1) and (2))
'''

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

df['starting_number'] = df['video_name'].apply(lambda x: x.split('_')[0])
c = df['starting_number'].map(video_color_mapping) 

### plot the pcas for the short term, long term, and all embeddings ### 
ax[0].scatter(short_term_pca[:, 0], short_term_pca[:, 1], c=c, s=10)
ax[0].set_title(f'Short term PCA explained variance: {round(sum(ev_short_term)*100)}%')
ax[0].set_xlabel('PC1')
ax[0].set_ylabel('PC2')
ax[1].scatter(long_term_pca[:, 0], long_term_pca[:, 1], c=c, s=10)
ax[1].set_title(f'Long term PCA explained variance: {round(sum(ev_long_term)*100)}%')
ax[2].scatter(all_pca[:, 0], all_pca[:, 1], c=c, s=10)
ax[2].set_title(f'All PCA explained variance: {round(sum(ev_all)*100)}%')

handles_numbers = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in video_number_color_mapping.values()]
labels_numbers = [number for number in video_number_color_mapping.keys()]

treeshrew_handle = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in ts_colormap]
rat_handle = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in rat_colormap]

handles_species = treeshrew_handle + rat_handle
labels_species = [f'Treeshrew' for i in range(len(ts_colormap))] + [f'Rat' for i in range(len(rat_colormap))]

### figure out how to not hard code this-- it would probably be easiest to include the animal identity in the file naming ###

labels_species[0] = 'Treeshrew (1)'
labels_species[1] = 'Treeshrew (2)'
labels_species[2] = 'Treeshrew (2)'
labels_species[3] = 'Treeshrew (2)'
labels_species[4] = 'Treeshrew (2)'

first_legend = fig.legend(handles_numbers, labels_numbers, loc='upper right', title='Video', bbox_to_anchor=(1, 0.8))
second_legend = fig.legend(handles_species, labels_species, loc='upper left', title='Species', bbox_to_anchor=(1, 0.8))

plt.gca().add_artist(first_legend)
plt.gca().add_artist(second_legend)

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the 2d pca plot ###
#plt.savefig(os.path.join(model_folder,"2dpca.png"),bbox_inches='tight')

# %% [markdown]
# # Create the Pearson correlation matrices for the short and long term sequence level embeddings

# %%
short_term_seq_np = short_term_seq.numpy()
long_term_seq_np = long_term_seq.numpy()
all_embeddings_seq_np = all_embeddings_seq.numpy()

print("short_term: ", np.shape(short_term_seq_np))
print("long_term: ", np.shape(long_term_seq_np))

def plot_correlation_heatmap(ax, data, title):
    corr_matrix = np.corrcoef(data, rowvar=False) ### setting rowvar=False because the columns contain the features and the rows contain the observations ###
    sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", ax=ax, vmin=-1, vmax=1)
    ax.set_title(title)

    ticks = np.arange(0, data.shape[1], 2)
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    ax.set_xticklabels(ticks)
    ax.set_yticklabels(ticks)

fig, ax = plt.subplots(1, 2, figsize=(24, 8))

plot_correlation_heatmap(ax[0], short_term_seq_np, "Short Term Sequence")
plot_correlation_heatmap(ax[1], long_term_seq_np, "Long Term Sequence")
# Out:
# short_term:  (119, 64)
# long_term:  (119, 64)

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the pearson correlation plot ###
#plt.savefig(os.path.join(model_folder,"pc_seq.png"),bbox_inches='tight')

# %% [markdown]
# # Predict species from sequence level embeddings

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression

from sklearn.neural_network import MLPClassifier

from sklearn import svm

from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import RidgeClassifier

import math

# %%
def add_scores(df, method, scores):
    new_data = pd.DataFrame({
        "Method": [method],
        "Accuracy": [scores["test_accuracy"].mean()],
        "Precision": [scores["test_precision"].mean()],
        "Recall": [scores["test_recall"].mean()],
        "F1": [scores["test_f1"].mean()]
    })
    return pd.concat([df, new_data], ignore_index=True)

folds = 5

df_out = pd.DataFrame(columns=["Method", "Accuracy", "Precision", "Recall", "F1"])

scoring = ['accuracy', 'precision', 'recall', 'f1']

out_path = os.path.join(model_folder,'model_scores_seqlevel.xlsx')

df = pd.read_csv(annotations_path)

print(df.head())

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from imblearn.under_sampling import RandomUnderSampler


sequences =  [short_term_seq, long_term_seq, all_embeddings_seq]
sequence_names = ['short_term_seq', 'long_term_seq', 'all_embeddings_seq']

results = {name: pd.DataFrame() for name in sequence_names}

for sequence, name in zip(sequences, sequence_names):
    X = sequence
    
    # only for sequence level
    X = X.view(X.size(0), -1)

    # only for frame level 
    #X = X.view(X.size(0) * X.size(1), X.size(2))
    
    X = X.numpy()

    y = df['label']

    print(np.shape(X))
    print(np.shape(y))

    unique_labels = df['label'].unique()
    label_mapping = {unique_labels[0]: 0, unique_labels[1]: 1}
    y = df['label'].map(label_mapping)

    # rus = RandomUnderSampler(random_state=0)
    # X_resampled, y_resampled = rus.fit_resample(X, y)

    ### if you want to randomly shuffle the labels for testing ###
    y_shuffled = np.random.permutation(y)

    # only for frame level
    #y = y.loc[y.index.repeat(short_term.size(1))].reset_index(drop=True)

    print("y shape :", np.shape(y))
    print("x shape :", np.shape(X))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    print(np.shape(X_train))
    print(np.shape(X_test))

    # Logistic Regression
    lr = LogisticRegression(max_iter=1000, random_state=42)
    scores_lr = cross_validate(lr, X_train, y_train, cv=folds, scoring=scoring)
    results[name] = add_scores(results[name], "LR", scores_lr)

    # # MLP
    # mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, random_state=42)
    # scores_mlp = cross_validate(mlp, X_train, y_train, cv=folds, scoring=scoring)
    # results[name] = add_scores(results[name], "MLP", scores_mlp)

    # SVM
    svm_model = svm.SVC()
    scores_svm = cross_validate(svm_model, X_train, y_train, cv=folds, scoring=scoring)
    results[name] = add_scores(results[name], "SVM", scores_svm)

    # KNN
    k = int(math.sqrt(len(y_train)))
    print(k)
    neigh = KNeighborsClassifier(n_neighbors=k)
    scores_neigh = cross_validate(neigh, X_train, y_train, cv=folds, scoring=scoring)
    results[name] = add_scores(results[name], "KNN", scores_neigh)

    # Ridge
    ridge = RidgeClassifier()
    scores_ridge = cross_validate(ridge, X_train, y_train, cv=folds, scoring = scoring)
    results[name] = add_scores(results[name], "RC", scores_ridge)

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the species predictions from the sequence level embeddings ###
    
#Save the results to an Excel file with separate sheets for each sequence
# with pd.ExcelWriter(out_path, engine='xlsxwriter') as writer:
#     for name, df_out in results.items():
#         df_out.to_excel(writer, sheet_name=name, index=False)

# %% [markdown]
# # Create 3D UMAP to explore frame level emebddings
# #### frame level embeddings are used to explore the latent space of the bams features

# %%
### reshape frame array ###

short_term_reshaped = short_term.view(short_term.size(0) * short_term.size(1), short_term.size(2))
long_term_reshaped = long_term.view(long_term.size(0) * long_term.size(1), long_term.size(2))
all_embeddings_reshaped = all_embeddings.view(all_embeddings.size(0) * all_embeddings.size(1), all_embeddings.size(2))

### print shapes before and after reshaping ###

print("short_term: ", np.shape(short_term))
print("long_term: ", np.shape(long_term))
print("all_embeddings: ", np.shape(all_embeddings))
print("")

print("short_term: ", np.shape(short_term_reshaped))
print("long_term: ", np.shape(long_term_reshaped))
print("all_embeddings: ", np.shape(all_embeddings_reshaped))
# Out:
# short_term:  torch.Size([119, 3600, 64])
# long_term:  torch.Size([119, 3600, 64])
# all_embeddings:  torch.Size([119, 3600, 128])
#
# short_term:  torch.Size([428400, 64])
# long_term:  torch.Size([428400, 64])
# all_embeddings:  torch.Size([428400, 128])

# %%
embedding = short_term
embedding_reshaped = short_term_reshaped
print(np.shape(embedding))
print(np.shape(embedding_reshaped))
# Out:
# torch.Size([119, 3600, 64])
# torch.Size([428400, 64])

# %%
''' 
for bsoid, every third frame is used  (see the compute function in bsoid_utils.py) 
HOWEVER, this will change due to the frame rate, so later versions of this code should account for this 
'''

### create mapping from bams embeddings to the video/ csv space ###

### read the order in which the csvs were passed to bams ###
df = pd.read_csv(annotations_path)
video = df['video_name']

### for each csv, repeat its name n frames per sample times ###
video = np.repeat(video, embedding.shape[1])
print(np.shape(video))

### for each csv, number the frames from 0 to n frames per sample ### 
if feature_processing == 'bsoid':
    repeated_array = np.tile(np.arange(2,embedding.shape[1]*3,3), embedding.shape[0])
else:
    repeated_array = np.tile(np.arange(embedding.shape[1]), embedding.shape[0])

print(np.shape(repeated_array))
# Out:
# (428400,)
# (428400,)

# %%
### make mapping that contains [video name, frame number] for each sample ###
video_frames = np.column_stack((video, repeated_array))

print(np.shape(video_frames))

### check ###
print(video_frames[1198])
# Out:
# (428400, 2)
# ['20231127_FrontDLC_resnet50_RatBody_CombinedApr29shuffle1_1100000_0_3600'
#  1198]

# %%
'''
I was just checking that the mapping from dlc csv frame to data point made sense
'''

### just checking ###

# for i in video_frames:
#     print(i)

# %% [markdown]
# ### UMAP

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
'''
due to the large size of the frame level dataset, a random sample of the data is selected to give to umap and dbscan
'''

### choose how many samples you want to plot ###
sample_size = 4000

os.mkdir(os.path.join(model_folder,f"{sample_size}"))

# %%
'''
the value of eps can be computed, however, I have found this doesn't well for our purpose 
see section 4.1 of https://dl.acm.org/doi/pdf/10.1145/3068335 for a description of the knee method for choosing eps
'''

from sklearn.neighbors import NearestNeighbors
import kneed

### how many neighbors will be used for DBSCAN? ###
k = 5

### randomly sample the input data for time/computation efficiency ### 
sample_indices = np.random.choice(len(embedding_reshaped), size=sample_size, replace=False)

sample = embedding_reshaped[sample_indices]
video_frames_sample = video_frames[sample_indices]

### for automating eps selection, you can use the knee method ### 

nbrs = NearestNeighbors(n_neighbors=k+1).fit(sample)

distances, indeces = nbrs.kneighbors(sample)

distances = np.sort(distances, axis=0)
distances = distances[:,1]

i = np.arange(len(distances))
knee = kneed.KneeLocator(i, distances, curve='convex', direction='increasing', online = False)
x = distances[knee.knee]

print("eps :", x)

plt.axhline(y=x, color='r', linestyle='-')

plt.plot(distances)
plt.show()
# Out:
# eps : 0.6277207995633994

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>
# ##### set eps and min_samples

# %%
import umap
from sklearn.cluster import DBSCAN

umap_model = umap.UMAP(n_components=3, random_state=42) 
behavior_umap = umap_model.fit_transform(sample)

### set eps and min_samples to a computed or  experimentally determined value ###
eps = 0.15
min_samples = 5

dbscan_model = DBSCAN(eps=0.15, min_samples=5) 
dbscan_labels = dbscan_model.fit_predict(behavior_umap)
# Out:
# c:\Users\MaryBeth\anaconda3\envs\bams_env\lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
### check shapes to make sure everything makes sense ###

print(np.shape(sample))
print(np.shape(video_frames_sample))
print(np.shape(dbscan_labels))
# Out:
# torch.Size([4000, 64])
# (4000, 2)
# (4000,)

# %%
import plotly.graph_objs as go

def index_to_time(index, frame_rate=30):

    total_seconds = index // frame_rate
    minutes = total_seconds // 60
    seconds = total_seconds % 60
    
    return f"{minutes}:{seconds:02d}"

unique_labels = np.unique(dbscan_labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
traces = []
for label, color in zip(unique_labels, colors):
    ### get points with the current label ###
    cluster_points = behavior_umap[dbscan_labels == label]
    video_frame_text = video_frames_sample[dbscan_labels == label]

    # print(np.shape(cluster_points))
    # print(np.shape(video_frame_text))
    
    ### add trace for the current label ### 
    traces.append(go.Scatter3d(
        x=cluster_points[:, 0],
        y=cluster_points[:, 1],
        z=cluster_points[:, 2],
        mode='markers',
        name=f'Cluster {label}' if label != -1 else 'Noise',
        marker=dict(
            size=3,
            color=f'rgb({color[0]*255},{color[1]*255},{color[2]*255})',
            opacity=0.8
        ),
        text=[f'{vf[0]} {vf[1]} {index_to_time(vf[1])}' for vf in video_frame_text],
    ))

layout = go.Layout(
    scene=dict(
        xaxis=dict(title='UMAP 1'),
        yaxis=dict(title='UMAP 2'),
        zaxis=dict(title='UMAP 3')
    ),
    margin=dict(l=0, r=0, b=0, t=0),  
    legend=dict(title='DBSCAN Clusters')
)

fig = go.Figure(data=traces, layout=layout)
fig.show()

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the umap ###

# fig.write_html(os.path.join(model_folder,f"{sample_size}",f"short_term_dbscan_{eps}_{min_samples}.html"))

# %% [markdown]
# ### Find the closest neighbors

# %%
'''
you can also explore the latent space by retrieving the closest neighbors to each a random data point
'''

from sklearn.metrics import pairwise_distances

neighbors = 5 

random_index = np.random.randint(0, sample.shape[0])
distances = pairwise_distances(sample[random_index].reshape(1, -1), sample).flatten()
nearest_neighbors = np.argsort(distances)[1:neighbors+1]

print("Random index:", random_index)
print("Sample:", video_frames_sample[random_index], "Cluster:", dbscan_labels[random_index])
print("")
print("nearest neighbors:")
for idx in nearest_neighbors:
    print(f"neighbor {idx}: {video_frames_sample[idx]},  cluster: {dbscan_labels[idx]}")

# %% [markdown]
# ## Save the the data points in each cluster as gifs

# %%
'''
to save each data point as a gif to its cluster folder, you will need the mp4s corresponding to the sample csvs in the dlc data folder
the mp4 folder should be organized with all of the mp4s in it (do not organize into subfolders for each label/species) ]

the gifs will be 1 second long (14 frames before the data point frame and 15 frames after-- but you can change this in the code below) 
it is easiest to watch them on loop 
'''

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### only need to change this if you want to change the input dataset ###
mp4_folder = r"X:\MaryBeth\BAMS\bams_collab\models\threshold_0.8\0.8_mp4s_combined"

# %%
import cv2

output_dir = os.path.join(model_folder, f"output_gifs_{eps}_{min_samples}")
os.makedirs(output_dir, exist_ok=True)

### get all of the unique video names ###
unique_video_names = np.unique([vf[0] for vf in video_frames_sample])

### get all of the unique dbscan labels ###
unique_labels = np.unique(dbscan_labels)

for video_name in unique_video_names:
    ### get the indices that correspond to the current video name ###
    relevant_indices = [i for i, vf in enumerate(video_frames_sample) if vf[0] == video_name]

    ### extract the video file name from the video_name variable ###
    video_base_name = video_name.split('DLC')[0]
    start_frame = video_name.split('_')[-2]
    end_frame = video_name.split('_')[-1]

    new_video_name = video_base_name + '_' + start_frame + '_' + end_frame

    ### construct the full path to the video file ###
    mp4_path = os.path.join(mp4_folder, new_video_name + '.mp4')

    ### get the mp4 ###
    cap = cv2.VideoCapture(mp4_path)
    if not cap.isOpened():
        print(f"Error opening video file {mp4_path}")
        continue

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    ### for each label in all of the dbscan labels ###
    for label in unique_labels:

        ### make a directory for it ###
        label_dir = os.path.join(output_dir, f"{sample_size}", f"cluster_{label}")
        os.makedirs(label_dir, exist_ok=True)

        ### search relevant indeces (the indeces that contain the video) for dbscan labels that match the current label ###
        label_indices = [i for i in relevant_indices if dbscan_labels[i] == label]
        print(label_indices)
        
        #### for each indeces that matches both the video and the dbscan label ###
        for i in label_indices:

            vf = video_frames_sample[i]
            frame_index = int(vf[1])

            ### get 0.5 sec before and after ###
            frame_start = max(frame_index - 14, 0)
            frame_end = frame_index + 15

            ### construct the output path for the gif ###
            output_video_path = os.path.join(label_dir, f"{new_video_name}_frame_{frame_index}.mp4")
            out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))
            
            ### read the first frame ###
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_start)
            
            ### read and write each frame within the sec range ###
            for j in range(frame_start, frame_end + 1):
                ret, frame = cap.read()
                if not ret:
                    print(f"Error reading frame {j} from {new_video_name}")
             
                out.write(frame)
            ### release the VideoWriter for this segment ###
            out.release()  
    ### release the video capture object after processing the current video ###
    cap.release()
# Out:
# [361, 376, 524, 675, 719, 859, 881, 930, 1085, 1145, 1224, 2086, 2109, 2211, 2435, 2512, 2778, 2844, 3002, 3367, 3387]
# []
# [161]
# [79, 2460]
# [1896]
# []
# []
# [1279]
# [2084]
# []
# [2033]
# [3998]
# []
# []
# [806, 839, 2985, 3440]
# []
# []
# []
# []
# [1228]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1524]
# [3668]
# []
# []
# [256, 1055, 2233]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [294]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [713, 3927]
# []
# []
# []
# []
# []
# [3304]
# []
# []
# []
# []
# [1648]
# []
# []
# []
# [3620]
# []
# []
# []
# []
# []
# []
# []
# [1360]
# []
# []
# []
# []
# []
# []
# [3904]
# []
# []
# []
# []
# []
# []
# []
# []
# [197]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [189, 658, 812, 866, 1001, 1056, 1093, 1292, 1293, 1570, 1574, 2375, 2447, 2451, 2816, 2943, 2944, 3223, 3474]
# []
# []
# [378]
# [1671, 3537]
# []
# []
# []
# [114, 1099, 2413, 3716]
# []
# [837, 955]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2141, 3750]
# []
# []
# []
# []
# []
# [2371]
# []
# []
# []
# [2699]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3614]
# []
# [210]
# [1434, 1489]
# []
# []
# []
# []
# [2664]
# []
# []
# []
# []
# [2426]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3277]
# []
# []
# [1921]
# []
# []
# []
# []
# []
# []
# []
# [3670]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3211]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [512]
# []
# []
# []
# []
# [325, 509, 752, 962, 1281, 1525, 1762, 1854, 1936, 2047, 2287, 3039, 3261, 3630, 3761, 3852, 3862]
# []
# [100, 2684, 3276]
# []
# []
# []
# []
# [354, 2955]
# [87, 1459, 1873]
# []
# []
# []
# []
# []
# [2698]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [104]
# []
# []
# []
# []
# [1213, 3663]
# []
# []
# []
# [1245]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2715]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [667]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1169]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2776]
# []
# [1868]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [394]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1503]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [257, 497, 1107, 1115, 1270, 1844, 2583, 2970, 3052, 3241, 3462, 3569, 3868, 3914]
# []
# []
# []
# [1182, 2937]
# []
# []
# [3024]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3094]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [125]
# []
# []
# []
# []
# []
# [302]
# [1633]
# []
# []
# []
# []
# []
# []
# []
# []
# [820]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [209, 501, 677, 1569, 1694, 1944, 2026, 2443, 2836, 3318, 3404, 3437, 3543, 3977]
# []
# [847]
# []
# [1769, 2591]
# []
# []
# []
# [925, 1079, 2761, 3575, 3873]
# []
# []
# []
# []
# []
# []
# []
# []
# [2328]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [982]
# []
# [1829]
# []
# []
# []
# []
# [3841]
# []
# []
# [3577]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3153]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [784]
# [1248]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1930]
# []
# []
# [3775]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
#

# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3702]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2269, 3631]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1882]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [90, 475, 861, 1242, 1665, 1718, 1905, 2299, 2935, 3742, 3752]
# []
# [1235]
# [3712]
# [195, 2825]
# []
# [1447]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3254]
# [676, 1393]
# []
# []
# []
# []
# [610]
# []
# [144]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1320, 1625, 1804, 1943, 2129]
# []
# []
# [2703]
# []
# []
# []
# []
# []
# [613]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2518]
# [2556]
# []
# []
# []
# [3238]
# []
# []
# []
# []
# [2959]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3509]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [10, 204, 253, 333, 362, 855, 1160, 1563, 1592, 2351, 2385, 2467, 2513, 2631, 2735, 3028, 3183, 3188, 3310, 3407, 3416, 3447, 3529, 3666, 3890]
# Error reading frame 3600 from 20230609_Front_61200_64800
# Error reading frame 3601 from 20230609_Front_61200_64800
# Error reading frame 3602 from 20230609_Front_61200_64800
# Error reading frame 3603 from 20230609_Front_61200_64800
# Error reading frame 3604 from 20230609_Front_61200_64800
# Error reading frame 3605 from 20230609_Front_61200_64800
# Error reading frame 3606 from 20230609_Front_61200_64800
# Error reading frame 3607 from 20230609_Front_61200_64800
# Error reading frame 3608 from 20230609_Front_61200_64800
# Error reading frame 3609 from 20230609_Front_61200_64800
# []
# []
# [639]
# [389, 1121, 2903, 3092]
# []
# []
# [3895]
# [1063, 1195, 2090, 2898, 3026]
# []
# [2700]
# []
# [1859]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [81, 1613]
# []
# []
# []
# []
# []
# [329]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [483, 2151]
# []
# []
# [1030, 1414, 3723]
# []
# []
# []
# [739]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1505]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2, 415, 985, 1872, 2296, 2300, 2421, 2669, 2964, 3090, 3426, 3999]
# []
# []
# [2068]
# [1858, 2029]
# []
# []
# []
# []
# []
# []
# []
# [3838]
# []
# [3196]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1866]
# []
# [750, 1431]
# []
# []
# []
# [3388]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1848, 2974, 3738]
# []
# []
# [575, 3799]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [14]
# []
# []
# []
# []
# [414]
# [1230]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2738]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3075]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [238, 364, 431, 469, 835, 921, 1075, 1156, 1184, 1221, 1711, 1830, 2083, 2349, 2549, 3152, 3212, 3850]
# []
# []
# []
# [823, 1157, 2648, 3251, 3849]
# []
# []
# []
# [2720]
# []
# []
# []
# []
# []
# []
# []
# [50]
# []
# []
# [146, 618, 1684]
# []
# [1100]
# Error reading frame 3600 from 20230609_Front_68400_72000
# Error reading frame 3601 from 20230609_Front_68400_72000
# Error reading frame 3602 from 20230609_Front_68400_72000
# Error reading frame 3603 from 20230609_Front_68400_72000
# Error reading frame 3604 from 20230609_Front_68400_72000
# Error reading frame 3605 from 20230609_Front_68400_72000
# []
# []
# []
# []
# []
# []
# []
# []
# [3410]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2289]
# []
# []
# []
# []
# []
# [779]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2643]
# []
# []
# []
# [3331, 3530]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [9, 553, 754, 2020, 2551]
# []
# []
# [3652]
# [2115, 3741]
# [810]
# []
# []
# [83, 1607, 2665]
# []
# []
# []
# [2950]
# []
# [2335]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2794]
# []
# []
# [372]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1341]
# []
# []
# []
# []
# []
# []
# [259]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2540]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3767]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2847]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [21, 212, 300, 383, 856, 943, 1142, 1192, 1254, 1972, 2134, 2302, 2710, 3148, 3247, 3731, 3907]
# []
# [2771]
# []
# [3724]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [

# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [508]
# []
# [3899]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3242]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3461]
# []
# []
# []
# []
# []
# []
# []
# [2281]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1193]
# [1047, 1841]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [105, 544, 627, 692, 818, 840, 1933, 2043, 2078, 2342, 2630, 3514, 3550, 3747, 3816]
# Error reading frame 3600 from 20230615_Front_10800_14400
# Error reading frame 3601 from 20230615_Front_10800_14400
# Error reading frame 3602 from 20230615_Front_10800_14400
# Error reading frame 3603 from 20230615_Front_10800_14400
# Error reading frame 3604 from 20230615_Front_10800_14400
# Error reading frame 3605 from 20230615_Front_10800_14400
# Error reading frame 3606 from 20230615_Front_10800_14400
# Error reading frame 3607 from 20230615_Front_10800_14400
# Error reading frame 3608 from 20230615_Front_10800_14400
# Error reading frame 3609 from 20230615_Front_10800_14400
# Error reading frame 3610 from 20230615_Front_10800_14400
# Error reading frame 3611 from 20230615_Front_10800_14400
# Error reading frame 3612 from 20230615_Front_10800_14400
# Error reading frame 3613 from 20230615_Front_10800_14400
# Error reading frame 3614 from 20230615_Front_10800_14400
# [3029]
# [3647]
# [1234]
# []
# [1297]
# []
# []
# [3628]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [190, 971, 1889]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1785, 2861]
# []
# []
# []
# []
# [496]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1978]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2765]
# []
# []
# [2323, 3906]
# [3344]
# [1051]
# []
# [3379]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2988]
# []
# []
# []
# []
# []
# []
# []
# []
# [2693]
# []
# [443, 2067, 2769]
# []
# []
# []
# []
# [963, 1605, 3113]
# []
# []
# [99, 288, 895, 1003, 1144, 1217, 1509, 1924, 2203, 2263, 2482, 2667, 2792, 2852, 3064, 3176, 3230, 3431, 3449]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1342]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3803]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1487]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2258]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1750, 2165]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [172, 436, 1198, 1616, 2623]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1020]
# []
# []
# []
# []
# []
# []
# []
# []
# [121, 275, 1257, 1291, 1502, 2195, 2245, 2248, 2436, 2466, 3104, 3168, 3501, 3780, 3844]
# Error reading frame 3600 from 20230615_Front_25200_28800
# Error reading frame 3601 from 20230615_Front_25200_28800
# Error reading frame 3602 from 20230615_Front_25200_28800
# Error reading frame 3603 from 20230615_Front_25200_28800
# Error reading frame 3604 from 20230615_Front_25200_28800
# Error reading frame 3605 from 20230615_Front_25200_28800
# []
# []
# []
# []
# []
# []
# []
# []
# [117]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [854]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2378]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [36, 583, 596, 1474, 1946, 2424, 2479, 2879, 3025, 3496]
# []
# []
# []
# []
# [1784, 2183, 3228]
# []
# []
# [397, 2002, 3280, 3898]
# []
# []
# []
# []
# []
# []
# [2785, 3362]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3675]
# []
# []
# [1451]
# []
# []
# []
# []
# []
# []
# []
# []
# [2639]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1877]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3915]
# [2929]
# []
# []
# []
# []
# []
# []
# []
# [790]
# []
# []
# [1317]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1794]
# []
# [96, 171, 669, 1073, 1315, 1550, 1557, 2149, 2383, 2599, 2856, 3726]
# []
# []
# [1367, 2442]
# []
# []
# []
# []
# [88, 674, 813]
# []
# []
# []
# []
# []
# []
# []
# [2726]
# []
# []
# []
# []
# []
# []
# []
# []
# [2916]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3864]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2234]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [324, 1446]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3165]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [

# []
# []
# []
# []
# []
# []
# []
# []
# []
# [293, 1000, 3760]
# []
# []
# []
# [1171, 1334, 3495, 3607]
# []
# []
# []
# []
# []
# [761, 2218, 3774]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [260, 828, 1990, 2553, 3082]
# []
# []
# []
# []
# []
# []
# []
# []
# [736]
# [1798]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [902]
# []
# []
# []
# [788, 1953, 2170]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [102, 218, 612, 874, 998, 1187, 1672, 2119, 2159, 2337, 2476, 2751, 2983, 2986, 3292, 3338, 3878, 3903]
# []
# [3502]
# []
# []
# []
# []
# [2046]
# []
# []
# []
# []
# []
# []
# []
# []
# [295]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [84]
# []
# [1571]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3665]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [270]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1035, 3833]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [995]
# []
# []
# [666]
# []
# []
# []
# []
# [1515]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3309]
# []
# []
# []
# [45, 156, 529, 2162, 2592, 2827, 3403]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [49, 1143, 1456, 1939, 2840, 3089]
# []
# [2660]
# []
# [1288, 3827]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1101]
# []
# []
# []
# []
# [1319, 2702]
# []
# [98, 187, 1590, 2071, 2101, 3222, 3621, 3768]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1364, 3463]
# []
# []
# []
# [579, 830, 1759]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [32, 1796]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [373, 470, 2168, 2221, 2369, 2406, 2452, 2575, 3776, 3791, 3965]
# []
# []
# [3633]
# []
# []
# []
# []
# []
# []
# [2511]
# []
# []
# []
# [184, 451, 467]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [427, 1422, 2196, 3958, 3992]
# []
# [142, 154, 685, 687, 1067, 1089, 1130, 2072, 2877, 3552, 3609, 3794]
# []
# [1660]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [2187, 2760]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3615, 3638]
# Error reading frame 3600 from 20231127_Front_46800_50400
# Error reading frame 3601 from 20231127_Front_46800_50400
# Error reading frame 3602 from 20231127_Front_46800_50400
# Error reading frame 3603 from 20231127_Front_46800_50400
# Error reading frame 3604 from 20231127_Front_46800_50400
# Error reading frame 3605 from 20231127_Front_46800_50400
# Error reading frame 3606 from 20231127_Front_46800_50400
# Error reading frame 3607 from 20231127_Front_46800_50400
# Error reading frame 3608 from 20231127_Front_46800_50400
# Error reading frame 3609 from 20231127_Front_46800_50400
# Error reading frame 3610 from 20231127_Front_46800_50400
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1025]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [33, 1382, 1432, 1837, 1885, 2057, 2073, 2305, 2647, 2743, 2810, 3433, 3510, 3784, 3830, 3957]
# []
# [1365]
# []
# []
# []
# []
# [452]
# []
# []
# []
# []
# []
# []
# []
# [2923]
# [3693]
# [3686]
# [3319]
# []
# []
# []
# []
# []
# []
# []
# [803]
# []
# [3905]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3545]
# []
# []
# []
# []
# [2498]
# []
# []
# []
# []
# []
# []
# []
# []
# [345]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3122, 3328]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [15, 25, 792, 1329, 1350, 1358, 1460, 2053, 2255, 2310, 2446, 2453, 2995, 3055, 3600, 3618, 3680, 3720, 3869]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [261, 3037]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3427]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [3220]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [916, 2016, 2060, 2140, 2260, 2320, 2722, 3273]

# %% [markdown]
# ### Plot the centroids of each data point on x,y plot of cage space

# %%
''' 
this only makes sense to do for x,y and x,y - centroid features, not bsoid features
for x,y it should be clear that the model is learning cage location 
for x,y - centroid all of the behavior clusters should be around the origin

note, because the origin of dlc (0,0) is in the upper left corner of the image, the animal location in cage space will appear
to be flipped over a y axis
'''

# %%
print(np.shape(model_input))
model_input_reshaped = model_input.reshape(model_input.shape[0] * model_input.shape[1], model_input.shape[2])
print(np.shape(model_input_reshaped))

# %%
### index by the same sample indeces as above ### 
keypoints_reshaped_sample = model_input_reshaped[sample_indices]

xs = keypoints_reshaped_sample[:,0::2]
ys = keypoints_reshaped_sample[:,1::2]

print(np.shape(xs))
print(np.shape(ys))

### average the x and y coordinates for each body part for each data point
x_centroids = np.mean(xs, axis = 1)
y_centroids = np.mean(ys, axis = 1)

print(np.shape(x_centroids))
print(np.shape(y_centroids))

# %% [markdown]
# #### Using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

### remove the cluster with label -1 ###
mask = dbscan_labels != -1
filtered_x_centroids = x_centroids[mask]
filtered_y_centroids = y_centroids[mask]
filtered_labels = dbscan_labels[mask]

### get all of the unique dbscan labels ###
unique_labels = np.unique(filtered_labels)

### make a color map for the unique labels ###
colors = plt.cm.get_cmap('tab20', len(unique_labels))  

### map each unique label to a color ###
color_mapping = {label: colors(i) for i, label in enumerate(unique_labels)}

### map the filtered labels to the corresponding colors ###
color_list = [color_mapping[label] for label in filtered_labels]

plt.figure(figsize=(10, 8))
scatter = plt.scatter(filtered_x_centroids, filtered_y_centroids, c=color_list, s=50, alpha=0.7)

# ### add the cluter labels next to each dot ###
# for i, label in enumerate(filtered_labels):
#      plt.text(filtered_x_centroids[i], filtered_y_centroids[i], str(label), fontsize=9, ha='right')

### adding plot title and labels ###
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")

#### create a custom legend ###
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_mapping[label], markersize=10) for label in unique_labels]
plt.legend(handles, unique_labels, title="Cluster Label")

plt.show()

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the centroids plot ###
#plt.savefig(os.path.join(model_folder,"centroids.png"),bbox_inches='tight')

# %% [markdown]
# #### Using Plotly

# %%
import plotly.graph_objects as go
import numpy as np

### remove the cluster with label -1 ###
mask = dbscan_labels != -1
filtered_x_centroids = x_centroids[mask]
filtered_y_centroids = y_centroids[mask]
filtered_labels = dbscan_labels[mask]

### get all of the unique dbscan labels ###
unique_labels = np.unique(filtered_labels)


### make a color map for the unique labels ###
colors = [f'rgba({int(np.random.rand()*255)}, {int(np.random.rand()*255)}, {int(np.random.rand()*255)}, 0.8)' for _ in unique_labels]
color_mapping = {label: color for label, color in zip(unique_labels, colors)}

### assign colors to each point based on its label ###
color_list = [color_mapping[label] for label in filtered_labels]

### create the scatter plot ###
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=filtered_x_centroids,
    y=filtered_y_centroids,
    mode='markers+text',
    text=filtered_labels,
    textposition='top right',
    marker=dict(color=color_list, size=10, opacity=0.7),
    showlegend=False
))

### customize axes and layout ###
fig.update_layout(
    xaxis_title="X Coordinate",
    yaxis_title="Y Coordinate",
    title="DBSCAN Cluster Centroids",
    template="plotly_white",
)

fig.update_yaxes(
    scaleanchor="x",
    scaleratio=1,
  )

#fig.show()

# %% [markdown]
# <span style="color:Red; font-size:24px;">User input</span>

# %%
### uncomment if you want to save the centroids plot ###
#fig.write_html(os.path.join(model_folder,"centroids_plotly.html"))
